# %%
import os
import sys
import pandas as pd 
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import mat4py as mt

# %%
sys.path.append(os.getcwd())

basefolder = r'/home/server/pi/homes/heminwas/aeolis_sed' 

aeolis_directory = r'/home/server/pi/homes/heminwas/aeolis_sed/aeolis-python/aeolis'
model_directory = r'/home/server/pi/homes/heminwas/aeolis_sed/aeolis-python/aeolis/examples/longterm_dune_growth'

sys.path.append(aeolis_directory)
from console_debug import *

scenario = 'aeolis'
run = os.path.join(model_directory, scenario +str('.txt'))

aeolis_debug(run)
# Out:
# **********************************************************
#
#          d8888                   888      d8b  .d8888b.
#         d88888                   888      Y8P d88P  Y88b
#        d88P888                   888          Y88b.
#       d88P 888  .d88b.   .d88b.  888      888  "Y888b.
#      d88P  888 d8P  Y8b d88""88b 888      888     "Y88b.
#     d88P   888 88888888 888  888 888      888       "888
#    d8888888888 Y8b.     Y88..88P 888      888 Y88b  d88P
#   d88P     888  "Y8888   "Y88P"  88888888 888  "Y8888P"
#
#   Version:  3.0.1
#
# **********************************************************
# PARAMETER SETTINGS
# **********************************************************
#   Aa                      = 0.085000
#   CFL                     = 1.00
#   Cb                      = 1.50
#   Cdk                     = 5.00
#   Ck                      = 2.78
#   Cl                      = 6.70
#   Cl_gw                   = 0.200000
#   Cs                      = 0.001100
#   D_gw                    = 12
#   GW_stat                 = 1
#   K_gw                    = 0.000100
#   L                       = 100.00
#   T                       = 1.00
#   Tbedreset               = 86400.00
#   Tdry                    = 5400.00
#   Tsalt                   = 2592000.00
#   V_lat                   = 0.500000
#   V_ver                   = 0.750000
#   accfac                  = 1.00
#   alfa                    = 0
#   alfad_moist             = 0.038000
#   alfaw_moist             = 0.058000
#   avg_time                = 86400.00
#   beach_slope             = 0.015600
#   bed_file                = input_files/z_ext.grd
#   bedcomp_file            = <novalue>
#   beta                    = 130.00
#   bi                      = 1.00
#   boundary_gw             = no_flow
#   boundary_lateral        = circular
#   boundary_offshore       = constant
#   boundary_onshore        = gradient
#   buffer_width            = 10
#   c_b                     = 0.200000
#   callback                = callback.py:update
#   constant_offshore_flux  = 0.000000
#   constant_onshore_flux   = 0.000000
#   cpair                   = 0.001004
#   csalt                   = 0.035000
#   dt                      = 3600
#   dune_toe_elevation      = 4.40
#   dx                      = 1.00
#   dy                      = 1.00
#   dzb_interval            = 86400.00
#   dzb_opt                 = 0
#   eps                     = 0.001000
#   external_vars           =
#   facDOD                  = 0.100000
#   fc                      = 0.110000
#   fence_file              = <novalue>
#   g                       = 9.81
#   gamma                   = 0.500000
#   gamma_vegshear          = 16.00
#   germinate               = 1.00
#   grain_dist              = 1.00
#   grain_size              = 0.000210
#   gw_mask                 = <novalue>
#   h                       = 10.00
#   hveg_max                = 0.300000
#   in_gw                   = 0
#   k                       = 0.030000
#   kappa                   = 0.410000
#   l                       = 10.00
#   lateral                 = 1.00
#   lateral_flux            = 0.000000
#   layer_thickness         = 0.050000
#   max_bedlevel_change     = 999
#   max_error               = 0.000001
#   max_iter                = 1000
#   max_iter_ava            = 1000
#   max_moist               = 10.00
#   md_moist                = 0.400000
#   meteo_file              = <novalue>
#   method_grainspeed       = duran
#   method_moist_process    = infiltration
#   method_moist_threshold  = belly_johnson
#   method_roughness        = constant_nikuradse
#   method_sed_supply       = constant_SCR_variable_tanB
#   method_shear            = fft
#   method_transport        = bagnold
#   method_wet_supply       = wet_bed_reset
#   mu_b                    = 30
#   mw_moist                = 0.800000
#   nd_moist                = 13.70
#   ne_file                 = input_files/ne_ext.grd
#   ne_gw                   = 0.300000
#   nfraction_sedtrails     = 0
#   nfractions              = 1
#   nlayers                 = 3
#   nw_moist                = 5.00
#   nx                      = 0
#   ny                      = 0
#   offshore_flux           = 0.000000
#   okin_c1_fence           = 0.480000
#   okin_c1_veg             = 0.480000
#   okin_initialred_fence   = 0.320000
#   okin_initialred_veg     = 0.320000
#   onshore_flux            = 0.000000
#   output_file             = /home/server/pi/homes/heminwas/aeolis_sed/aeolis-python/aeolis/examples/longterm_dune_growth/aeolis.nc
#   output_sedtrails        = F
#   output_times            = 172800
#   output_types            =
#   output_vars             = zb
#   porosity                = 0.400000
#   process_avalanche       = T
#   process_bedupdate       = T
#   process_dune_erosion    = T
#   process_fences          = F
#   process_groundwater     = F
#   process_humidity        = F
#   process_inertia         = F
#   process_meteo           = F
#   process_mixtoplayer     = F
#   process_moist           = T
#   process_runup           = T
#   process_salt            = F
#   process_scanning        = F
#   process_sediment_supply = T
#   process_seepage_face    = F
#   process_separation      = F
#   process_shear           = F
#   process_threshold       = T
#   process_tide            = T
#   process_transport       = T
#   process_vegetation      = T
#   process_wave            = T
#   process_wet_bed_reset   = F
#   process_wet_supply      = F
#   process_wind            = T
#   refdate                 = 1997-09-17
#   resd_moist              = 0.010000
#   restart                 = <novalue>
#   resw_moist              = 0.010000
#   rhoa                    = 1.23
#   rhog                    = 2650.00
#   rhoveg_max              = 0.500000
#   rhow                    = 1025.00
#   runup_mask              = <novalue>
#   satd_moist              = 0.300000
#   satw_moist              = 0.300000
#   scheme                  = euler_backward
#   sedimentinput           = 0.000000
#   sep_filter_iterations   = 0
#   shoreline_change_rate   = 2.87
#   sigma                   = 4.20
#   solver                  = pieter
#   supply_file             = <novalue>
#   t_veg                   = 3
#   tfac_gw                 = 30
#   th_bedslope             = T
#   th_drylayer             = F
#   th_grainsize            = T
#   th_humidity             = F
#   th_moisture             = T
#   th_nelayer              = T
#   th_roughness            = T
#   th_salt                 = F
#   th_sheltering           = F
#   theta_dyn               = 33.00
#   theta_stat              = 34.00
#   thick_moist             = 0.002000
#   threshold_file          = <novalue>
#   threshold_mask          = <novalue>
#   tide_file               = input_files/tide.txt
#   tide_mask               = <novalue>
#   tstart                  = 0
#   tstop                   = 812862000
#   v                       = 0.000015
#   v_gam                   = 1
#   veg_file                = input_files/q_veg_ext.grd
#   veg_gamma               = 1.00
#   veg_min_elevation       = 4.40
#   veg_sigma               = 0.800000
#   veggrowth_type          = orig
#   vegshear_type           = raupach
#   visualization           = F
#   vver_mask               = <novalue>
#   w1_5                    = 0.020000
#   wave_file               = input_files/wave.txt
#   wave_mask               = <novalue>
#   wind_convention         = nautical
#   wind_file               = input_files/wind_nooffshore.txt
#   xgrid_file              = input_files/x_ext.grd
#   xi                      = 0.300000
#   xshoreline              = 0
#   ygrid_file              = input_files/y_ext.grd
#   z                       = 10.00
#   zsep_y_filter           = F
#   zshoreline              = 0
# **********************************************************
#
# Applying callback function: update()
# AeoLiS  Copyright (C) 2015  Bas Hoonhout
# This program comes with ABSOLUTELY NO WARRANTY.
# This is free software, and you are welcome to redistribute it
# under certain conditions; See LICENSE.txt for details.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 14
#      10
#      11 scenario = 'aeolis'
#      12 run = os.path.join(model_directory, scenario +str('.txt'))
#      13
# ---> 14 aeolis_debug(run)
#
# File ~/aeolis_sed/aeolis-python/aeolis/console_debug.py:62, in aeolis_debug(configfile)
#      60 # start model
#      61 model = AeoLiSRunner(configfile=configfile)
# ---> 62 model.run()
#
# File ~/aeolis_sed/aeolis-python/aeolis/model.py:2802, in AeoLiSRunner.run(self, callback, restartfile)
#    2800 while self.t <= self.p['tstop']:
#    2801     if callback is not None:
# -> 2802         callback(self)
#    2803     self.update()
#    2804     self.output_write()
#
# File ~/aeolis_sed/aeolis-python/aeolis/examples/longterm_dune_growth/callback.py:7, in update(model)
#       6 def update(model):
# ----> 7     rhoveg, hveg, vegetated = veg_mortality_fix(model.get_var('zb'),model.get_var('TWL'))
#       8     model.set_var('rhoveg', rhoveg)
#       9     model.set_var('hveg', hveg)
#
# File ~/aeolis_sed/aeolis-python/aeolis/examples/longterm_dune_growth/callback.py:17, in veg_mortality_fix(zb, TWL)
#      15 def veg_mortality_fix(zb, TWL):
#      16     #Fixes mortality bug within the model, only killing vegetation seaward of the TWL and profile intersection'
# ---> 17     veg_min_elevation = model.get_var('veg_min_elevation')
#      18     process_tide = model.get_var('process_tide')
#      20     rhoveg = model.get_var('rhoveg')
#
# AttributeError: module 'pyexpat.model' has no attribute 'get_var'

# %%
def extract_netcdf(file):
    
    run = nc.Dataset(file, 'r')
    time = run['time'][:]
    x =  run['x'][0,:] #baselineb['x'][1,:].values
    zbi = run['zb'][0,0,:] # baselineb['zb'][0,1,:].values 
    zbf = run['zb'][-1,0,:]
    zb_all = run['zb'][:,0,:]
    
    run.close()
    start_time = datetime(1997, 9, 17, 0, 0)
    dates = [start_time + timedelta(seconds = sec) for sec in time]
    
    return x, zbi, zbf, zb_all, time, dates

# %%
def plot(x, zb_all, time, figname ):
    colors_arr = plt.cm.viridis(np.linspace(0, 1, len(time)))
    fig = plt.figure(figsize = (8,5))
    plt.plot(x,zb_all[0,:], color = 'k', linestyle = '--', label = 'Initial Profile')
    for i in range(0, len(time)):
        if i==0 or i == len(time)-1:
            plt.plot(x, zb_all[i,:], color = colors_arr[i], label = str(dates[i])[:-8])
        else:
            plt.plot(x, zb_all[i,:], color = colors_arr[i])
    plt.ylabel('Elevation (m)', fontsize = 14)
    plt.xlabel('Cross-shore Distance (m)', fontsize = 14)
    plt.legend(loc = 'upper left')
    plt.savefig(figname)

# %%
file = scenario +'.nc'
path = os.path.join(model_directory, file)
fig_folder = os.path.join(model_directory,'figures')

x, zbi, zbf, zb_all, time, dates = extract_netcdf(path,fig_folder) 
fig1 = plot(x, zb_all, time, 'aeolis_ex.png')
